# %%
from PIL import Image
import pytesseract
import argparse #currently not working
import cv2
import os
import sys
import numpy as np
#import tesseract
from IPython.display import Image, display
from matplotlib import pyplot as plt

# %%
#adding the path of tesseract
pytesseract.pytesseract.tesseract_cmd = r'/opt/anaconda3/envs/DA_Environment/bin/tesseract'

# %%
img = cv2.imread("data/IMG_20211003_152520.jpg")
plt.imshow(img)
plt.show()

# %%
print(pytesseract.image_to_string(img))
# Out:
# <@
# YY &
# md
# 5
# —
# a= &
# DY |
# =
# ~fF
# w -
# —
# ames
# S|
# —
# SS
# =<.
#
# Gemeinsamer Tarif der im Verkehrsverbund Berlin-Brandenburg
# Zusammenwirkenden Verkehrsunternehmen (VBB-Tarif)
#
# Gultig nach den geltenden BelOrderungsbedingungen
#
# BYG - Holzmarktstr, 15-17 . 10179 Berlin - Tel. 2
#
# 2560
#
# Fd ry
# , Fd
#
# #232326 1841

# %%
#print(pytesseract.image_to_boxes(Image.open('data/IMG_20211003_152520.jpg')))

# %%
img = cv2.imread("data/IMG_20211003_152520.jpg")
#Resize the image
img = cv2.resize(img, None, fx=0.5, fy=0.5)
#Convert image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#Convert image to black and white
new_image = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 85, 11)

text = pytesseract.image_to_string(new_image, config="--psm 3")
#print(text)
plt.imshow(new_image)
plt.show()

# %%
detector = EASTDetector()
slices = detector.get_slices(new_image)
titles = [pytesseract.image_to_string(img) for img in slices]
show_images(slices, titles=titles, cols=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-357f4d4aebf3> in <module>
# ----> 1 detector = EASTDetector()
#       2 slices = detector.get_slices(new_image)
#       3 titles = [pytesseract.image_to_string(img) for img in slices]
#       4 show_images(slices, titles=titles, cols=3)
#
# NameError: name 'EASTDetector' is not defined

# %%
narrowed = binarize_images(slices[2:], black_on_white=False)
narrowed = narrow_images(narrowed)
titles = [pytesseract.image_to_string(new_image) for img in narrowed]
show_images(narrowed, titles=titles, cols=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-3b811539a3e7> in <module>
# ----> 1 narrowed = binarize_images(slices[2:], black_on_white=False)
#       2 narrowed = narrow_images(narrowed)
#       3 titles = [pytesseract.image_to_string(new_image) for img in narrowed]
#       4 show_images(narrowed, titles=titles, cols=3)
#
# NameError: name 'binarize_images' is not defined
